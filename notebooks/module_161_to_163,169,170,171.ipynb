# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
df_copy=pd.read_csv('Data.csv')

# %%
df_copy
# Out:
#     day,month,year,Temperature,RH,Ws,Rain,FFMC,DMC,DC,ISI,BUI,FWI,Classes,Region
# 0    1,6,2012,29,57,18,0.0,65.7,3.4,7.6,1.3,3.4,0.5...
# 1    2,6,2012,29,61,13,1.3,64.4,4.1,7.6,1.0,3.9,0.4...
# 2    3,6,2012,26,82,22,13.1,47.1,2.5,7.1,0.3,2.7,0....
# 3    4,6,2012,25,89,13,2.5,28.6,1.3,6.9,0.0,1.7,0.0...
# 4    5,6,2012,27,77,16,0.0,64.8,3.0,14.2,1.2,3.9,0....
# ..                                                 ...
# 238  26,9,2012,30,65,14,0.0,85.4,16.0,44.5,4.5,16.9...
# 239  27,9,2012,28,87,15,4.4,41.1,6.5,8.0,0.1,6.2,0....
# 240  28,9,2012,27,87,29,0.5,45.9,3.5,7.9,0.4,3.4,0....
# 241  29,9,2012,24,54,18,0.1,79.7,4.3,15.2,1.7,5.1,0...
# 242  30,9,2012,24,64,15,0.2,67.3,3.8,16.5,1.2,4.8,0...
#
# [243 rows x 1 columns]

# %%
df=df_copy

# %%
df
# Out:
#     day,month,year,Temperature,RH,Ws,Rain,FFMC,DMC,DC,ISI,BUI,FWI,Classes,Region
# 0    1,6,2012,29,57,18,0.0,65.7,3.4,7.6,1.3,3.4,0.5...
# 1    2,6,2012,29,61,13,1.3,64.4,4.1,7.6,1.0,3.9,0.4...
# 2    3,6,2012,26,82,22,13.1,47.1,2.5,7.1,0.3,2.7,0....
# 3    4,6,2012,25,89,13,2.5,28.6,1.3,6.9,0.0,1.7,0.0...
# 4    5,6,2012,27,77,16,0.0,64.8,3.0,14.2,1.2,3.9,0....
# ..                                                 ...
# 238  26,9,2012,30,65,14,0.0,85.4,16.0,44.5,4.5,16.9...
# 239  27,9,2012,28,87,15,4.4,41.1,6.5,8.0,0.1,6.2,0....
# 240  28,9,2012,27,87,29,0.5,45.9,3.5,7.9,0.4,3.4,0....
# 241  29,9,2012,24,54,18,0.1,79.7,4.3,15.2,1.7,5.1,0...
# 242  30,9,2012,24,64,15,0.2,67.3,3.8,16.5,1.2,4.8,0...
#
# [243 rows x 1 columns]

# %%
#drop month day year
df.drop(['day','month','year'],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 2
#       1 #drop month day year
# ----> 2 df.drop(['day','month','year'],axis=1,inplace=True)
#
# File c:\Users\weare\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
df.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI      Classes  \
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5  not fire
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4  not fire
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1  not fire
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0  not fire
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5  not fire
#
#    Region
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df['Classes'].value_counts()
# Out:
# Classes
# fire             131
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: count, dtype: int64

# %%
##encoding 
df['Classes']=np.where(df['Classes'].str.contains("not fire"),0,1)

# %%
df.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0       0

# %%
df.tail()
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  Classes  \
# 238           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5        1
# 239           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0        0
# 240           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2        0
# 241           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7        0
# 242           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5        0
#
#      Region
# 238       1
# 239       1
# 240       1
# 241       1
# 242       1

# %%
df['Classes'].value_counts()
# Out:
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %%
##independant and dependant features
X=df.drop('FWI',axis=1)
Y=df['FWI']

# %%
X.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9        0       0

# %%
Y
# Out:
# 0      0.5
# 1      0.4
# 2      0.1
# 3      0.0
# 4      0.5
#       ...
# 238    6.5
# 239    0.0
# 240    0.2
# 241    0.7
# 242    0.5
# Name: FWI, Length: 243, dtype: float64

# %%
X
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  Classes  Region
# 0             29  57  18   0.0  65.7   3.4   7.6  1.3   3.4        0       0
# 1             29  61  13   1.3  64.4   4.1   7.6  1.0   3.9        0       0
# 2             26  82  22  13.1  47.1   2.5   7.1  0.3   2.7        0       0
# 3             25  89  13   2.5  28.6   1.3   6.9  0.0   1.7        0       0
# 4             27  77  16   0.0  64.8   3.0  14.2  1.2   3.9        0       0
# ..           ...  ..  ..   ...   ...   ...   ...  ...   ...      ...     ...
# 238           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9        1       1
# 239           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2        0       1
# 240           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4        0       1
# 241           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1        0       1
# 242           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8        0       1
#
# [243 rows x 11 columns]

# %%
## Train test split
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.25,random_state=42)

# %%
X_train.shape,X_test.shape
# Out:
# ((182, 11), (61, 11))

# %%
## feature selection based on correlation 
X_train.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.656095 -0.305977 -0.317512  0.694768  0.498173
# RH             -0.656095  1.000000  0.225736  0.241656 -0.653023 -0.414601
# Ws             -0.305977  0.225736  1.000000  0.251932 -0.190076  0.000379
# Rain           -0.317512  0.241656  0.251932  1.000000 -0.545491 -0.289754
# FFMC            0.694768 -0.653023 -0.190076 -0.545491  1.000000  0.620807
# DMC             0.498173 -0.414601  0.000379 -0.289754  0.620807  1.000000
# DC              0.390684 -0.236078  0.096576 -0.302341  0.524101  0.868647
# ISI             0.629848 -0.717804 -0.023558 -0.345707  0.750799  0.685656
# BUI             0.473609 -0.362317  0.035633 -0.300964  0.607210  0.983175
# Classes         0.542141 -0.456876 -0.082570 -0.369357  0.781259  0.617273
# Region          0.254549 -0.394665 -0.199969 -0.059022  0.249514  0.212582
#
#                    DC       ISI       BUI   Classes    Region
# ...

# %%
## check for multiple co-linearity 
plt.figure(figsize=(12,10))
corr=X_train.corr()
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
import seaborn as sns

# %%
def correlation(dataset, threshold):
    col_corr = set()
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i,j]) > threshold:
                colname = corr_matrix.columns[i]
                col_corr.add(colname)
                return col_corr

# %%
## thresold--Domain experties 
corr_features=correlation(X_train,0.90)

# %%
#
corr_features=correlation(X_train,0.87)

# %%
# drop co relation when correlation is more than 0.85
X_train.drop(corr_features,axis=1,inplace=True)
X_test.drop(corr_features,axis=1,inplace=True)
X_train.shape,X_test.shape
# Out:
# ((182, 10), (61, 10))

# %% [markdown]
# ### feature scaling or standardization

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[-0.84284248,  0.78307967,  1.29972026, ..., -0.62963326,
#         -1.10431526, -0.98907071],
#        [-0.30175842,  0.64950844, -0.59874754, ..., -0.93058524,
#         -1.10431526,  1.01105006],
#        [ 2.13311985, -2.08870172, -0.21905398, ...,  2.7271388 ,
#          0.90553851,  1.01105006],
#        ...,
#        [-1.9250106 ,  0.9166509 ,  0.54033314, ..., -1.06948615,
#         -1.10431526, -0.98907071],
#        [ 0.50986767, -0.21870454,  0.16063958, ...,  0.5973248 ,
#          0.90553851,  1.01105006],
#        [-0.57230045,  0.98343651,  2.05910739, ..., -0.86113478,
#         -1.10431526, -0.98907071]])

# %% [markdown]
# ## box plot to understand effect of standard scaler

# %%
plt.subplots(figsize=(30,10))
plt.subplot(1,2,1)
sns.boxplot(data=X_train)
plt.title('X_train_before_scaling')
plt.subplot(1,2,2)
sns.boxplot(data=X_train_scaled)
plt.title('X_train_after_scaling')

##plt.subplots(1, 2, figsize=(15, 5))
#This creates one row with two columns of subplots.
#1, 2 means 1 row and 2 columns, so two plots appear side by side.
# Out:
# Text(0.5, 1.0, 'X_train_after_scaling')

# %% [markdown]
# ## linear regression model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
linreg=LinearRegression()
linreg.fit(X_train_scaled,Y_train)
Y_pred=linreg.predict(X_test)## value shows negative insted of writing x_test_scaled i write X_test only 
mae=mean_absolute_error(Y_test,Y_pred)
score=r2_score(Y_test,Y_pred)
print("mean absolute error:",mae)
print("R2 score",score)
# Out:
# mean absolute error: 50.535241639745905
# R2 score -126.19235501624739
# C:\Users\weare\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
linreg=LinearRegression()
linreg.fit(X_train_scaled,Y_train)
Y_pred=linreg.predict(X_test_scaled)## value shows negative insted of writing x_test_scaled i write X_test only 
mae=mean_absolute_error(Y_test,Y_pred)
score=r2_score(Y_test,Y_pred)
print("mean absolute error:",mae)
print("R2 score",score)
# Out:
# mean absolute error: 0.5170107980662414
# R2 score 0.9830565611009444

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
linreg=LinearRegression()
linreg.fit(X_train_scaled,Y_train)
Y_pred=linreg.predict(X_test_scaled)## value shows negative insted of writing x_test_scaled i write X_test only 
mae=mean_absolute_error(Y_test,Y_pred)
score=r2_score(Y_test,Y_pred)
print("mean absolute error:",mae)
print("R2 score",score)
plt.scatter(Y_test,Y_pred)
# Out:
# mean absolute error: 0.5170107980662414
# R2 score 0.9830565611009444

# %% [markdown]
# ## Applying lasso regression

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
Lasso=Lasso()
Lasso.fit(X_train_scaled,Y_train)
Y_pred=Lasso.predict(X_test_scaled)
mae=mean_absolute_error(Y_test,Y_pred)
score=r2_score(Y_test,Y_pred)
print("mean absolute error:",mae)
print("R2 score",score)
plt.scatter(Y_test,Y_pred)
# Out:
# mean absolute error: 1.1257992990774723
# R2 score 0.9498931628519823

# %% [markdown]
# ## ridge regression

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
Ridge= Ridge()
Ridge.fit(X_train_scaled,Y_train)
Y_pred= Ridge.predict(X_test_scaled)
mae=mean_absolute_error(Y_test,Y_pred)
score=r2_score(Y_test,Y_pred)
print("mean absolute error:",mae)
print("R2 score",score)
# Out:
# mean absolute error: 0.5292519766274827
# R2 score 0.9824051915524251

# %% [markdown]
# #### Elastricnet regression combine of lasso and redge regresssion

# %%
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
Elastic= ElasticNet()
Elastic.fit(X_train_scaled,Y_train)
Y_pred= Elastic.predict(X_test_scaled)
mae=mean_absolute_error(Y_test,Y_pred)
score=r2_score(Y_test,Y_pred)
print("mean absolute error:",mae)
print("R2 score",score)
# Out:
# mean absolute error: 1.770425552142529
# R2 score 0.8887824924177792

# %% [markdown]
# ## cross validation

# %% [markdown]
# ###### lasso

# %%
from sklearn.linear_model import LassoCV
lassocv=LassoCV(cv=5)
lassocv.fit(X_train_scaled,Y_train)
# Out:
# LassoCV(cv=5)

# %%
lassocv.predict(X_test_scaled)
# Out:
# array([ 8.18538159e+00,  7.41345139e+00, -3.66821019e-02,  5.31348393e+00,
#         6.71815182e+00,  1.56140620e+00,  2.50472023e+00,  7.33361195e+00,
#         2.03398603e+00,  3.31843293e+00,  4.53876985e-01,  1.07417186e+01,
#         9.45933277e+00,  1.64871702e+01,  1.87193231e+01,  1.55727329e+00,
#         1.62851286e+00, -7.14990407e-01,  6.93533958e+00,  3.15977303e+00,
#         1.85650246e+00,  2.98332857e-01,  6.31153138e+00,  1.27875987e-02,
#         2.08098903e+01,  4.75489814e+00,  5.76643708e+00,  9.84031730e+00,
#        -7.19344449e-01,  9.97487451e+00,  6.49891967e+00, -1.49816524e-01,
#         1.02676265e+01,  1.47780964e+01,  1.56969036e+00,  1.00809100e+00,
#         1.95664505e+00,  5.98777428e+00, -4.77576376e-01, -3.60610024e-01,
#         6.83066604e+00,  1.84559577e+00,  8.22327832e+00, -8.83235816e-01,
#         1.53227870e+01,  7.99602462e+00,  8.07558228e+00,  9.84179193e-01,
# ...

# %%
lassocv.alphas_
# Out:
# array([7.05853002, 6.58280872, 6.13914944, 5.72539132, 5.33951911,
#        4.97965339, 4.64404142, 4.33104857, 4.03915039, 3.76692517,
#        3.51304702, 3.27627941, 3.05546914, 2.84954075, 2.65749124,
#        2.47838523, 2.31135036, 2.15557308, 2.01029467, 1.87480753,
#        1.74845178, 1.63061198, 1.52071419, 1.41822315, 1.32263965,
#        1.23349817, 1.15036452, 1.0728338 , 1.00052839, 0.93309613,
#        0.87020857, 0.81155943, 0.75686304, 0.705853  , 0.65828087,
#        0.61391494, 0.57253913, 0.53395191, 0.49796534, 0.46440414,
#        0.43310486, 0.40391504, 0.37669252, 0.3513047 , 0.32762794,
#        0.30554691, 0.28495408, 0.26574912, 0.24783852, 0.23113504,
#        0.21555731, 0.20102947, 0.18748075, 0.17484518, 0.1630612 ,
#        0.15207142, 0.14182231, 0.13226397, 0.12334982, 0.11503645,
#        0.10728338, 0.10005284, 0.09330961, 0.08702086, 0.08115594,
#        0.0756863 , 0.0705853 , 0.06582809, 0.06139149, 0.05725391,
# ...

# %%
Y_pred= lassocv.predict(X_test_scaled)
mae=mean_absolute_error(Y_test,Y_pred)
score=r2_score(Y_test,Y_pred)
print("mean absolute error:",mae)
print("R2 score",score)
plt.scatter(Y_test,Y_pred)
# Out:
# mean absolute error: 0.5537550153494092
# R2 score 0.9812242879221943

# %%
from sklearn.linear_model import RidgeCV
ridgecv=RidgeCV(cv=5)
ridgecv.fit(X_train_scaled,Y_train)
Y_pred= ridgecv.predict(X_test_scaled)
mae=mean_absolute_error(Y_test,Y_pred)
score=r2_score(Y_test,Y_pred)
print("mean absolute error:",mae)
print("R2 score",score)
plt.scatter(Y_test,Y_pred)
# Out:
# mean absolute error: 0.5292519766274827
# R2 score 0.9824051915524251

# %%
## how many number of alphas there and which alphas selected there
ridgecv.alphas
ridgecv.alpha_
# Out:
# 1.0

# %%
from sklearn.linear_model import ElasticNetCV
elasticcv=ElasticNetCV(cv=5)
elasticcv.fit(X_train_scaled,Y_train)
Y_pred= elasticcv.predict(X_test_scaled)
mae=mean_absolute_error(Y_test,Y_pred)
score=r2_score(Y_test,Y_pred)
print("mean absolute error:",mae)
print("R2 score",score)
plt.scatter(Y_test,Y_pred)
# Out:
# mean absolute error: 0.6133340328806132
# R2 score 0.9789643451363162

# %%
## picling machine learning models preprocessing model standardscaler
StandardScaler()
# Out:
# StandardScaler()

# %%
Ridge
# Out:
# Ridge()

# %%
import pickle
pickle.dump(scaler,open('scaler.pkl','wb'))
pickle.dump(Ridge,open('Ridge.pkl','wb'))
